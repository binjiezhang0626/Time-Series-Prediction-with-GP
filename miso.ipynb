# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
pop = pd.read_csv('pop.csv',sep=',')

# %%
print(pop)
# Out:
#               50          100         500        1000
# 0   4.083156e+02     0.000000    0.000000    0.000000
# 1   0.000000e+00   843.380000    0.111456    0.000000
# 2   6.843594e+01     0.000000  392.616041   36.312452
# 3   4.179600e+03     0.000000   98.358162    0.000000
# 4   0.000000e+00     0.000000    0.000000    0.000000
# 5   0.000000e+00   714.560000    0.000000  107.846858
# 6   0.000000e+00     0.000000   67.604779    0.000000
# 7   0.000000e+00     0.000000    0.000000  107.846858
# 8   0.000000e+00     0.007733  900.343442    4.000000
# 9   0.000000e+00     0.000000    0.000000    0.000000
# 10  0.000000e+00   126.626047    0.000000    0.000000
# 11  0.000000e+00     0.000000    0.000000    0.000000
# 12  3.854049e+01     0.000000    0.000000    0.000000
# 13  0.000000e+00     0.000000    0.000000   53.667716
# 14  0.000000e+00   795.175708    0.000000   64.000000
# 15  0.000000e+00     0.000000    0.000000    0.000000
# ...

# %%
plt.figure(figsize=(12,12))
pop.boxplot()
plt.title("Distribution of Population")
plt.xlabel("Population size")
plt.ylabel("Distribution")
plt.savefig("Distribution of Population.png")
plt.show()

# %%
mu = pd.read_csv('mu.csv',sep=',')

# %%
print(mu)
# Out:
#              0.2         0.4          0.6         0.8        0.99
# 0   0.000000e+00    0.000000   149.812754  384.045000    0.000000
# 1   2.042261e+02    0.000000     0.000000    4.000000    1.000000
# 2   0.000000e+00   36.312452   275.716033    0.000000    1.000000
# 3   0.000000e+00    0.000000    76.214430    0.000000  683.941103
# 4   0.000000e+00    0.000000     0.000000    1.438856   10.217884
# 5   0.000000e+00  107.846858     0.000000    0.000000    0.000000
# 6   0.000000e+00    0.000000     0.000000    0.000034  412.892392
# 7   0.000000e+00  107.846858     0.000000    0.675566    0.000000
# 8   0.000000e+00    4.000000     0.000000    0.000000    0.000000
# 9   7.316609e+02    0.000000     0.000000    0.000000  575.514719
# 10  0.000000e+00    0.000000     0.000000    0.000000   61.562708
# 11  0.000000e+00    0.000000     8.000000    0.000000    0.000000
# 12  0.000000e+00    0.000000     0.000000    0.000000    0.000000
# ...

# %%
plt.figure(figsize=(12,12))
mu.boxplot()
plt.title("Distribution of Mumation")
plt.xlabel("Mumation probability")
plt.ylabel("Distribution")
plt.savefig("Distribution of Mumation.png")
plt.show()

# %%
crossover = pd.read_csv('crossover.csv',sep=',')

# %%
print(crossover)
# Out:
#            0.25        0.45         0.65        0.85
# 0      0.000000  569.869058     0.000000    0.000000
# 1    616.400404    0.000000     0.000000    0.000000
# 2      1.000000    0.000000     0.000000   36.312452
# 3      0.000000    0.000000     0.000000    0.000000
# 4    332.942360    0.000000   436.700743    0.000000
# 5      0.000000    0.000000   387.418512  107.846858
# 6      0.000000    4.000000   382.725000    0.000000
# 7      0.000000    0.000000     0.000000  107.846858
# 8   1329.520269    0.000000     0.000000    4.000000
# 9      0.000000  558.872329   812.733012    0.000000
# 10     0.000000    0.000000     0.000000    0.000000
# 11   928.533127    0.000000     0.142777    0.000000
# 12   283.610376  348.114501   123.880957    0.000000
# 13   169.294613    2.199745     0.000000   53.667716
# 14   384.045000  749.939241     0.000000   64.000000
# 15     0.000000    0.000000     0.000000    0.000000
# 16   387.088876    0.000000   387.088876   98.358162
# ...

# %%
plt.figure(figsize=(12,12))
crossover.boxplot()
plt.title("Distribution of Mumation")
plt.xlabel("Mumation probability")
plt.ylabel("Distribution")
plt.savefig("Distribution of Mumation.png")
plt.show()
